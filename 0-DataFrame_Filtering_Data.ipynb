# %% [markdown]
# ## DataFrames: Filtering Data

# %% [markdown]
# 1-Filter A DataFrame Based On A Condition (Equal, Not equal, Greater than, Less than, Greater than or equal to, less than or equal to)
#
# 2-Filter with More than One Condition (AND)
#
# 3-Filter with More than One Condition (OR)
#
# 4-The .isin() Method
#
# 5-The .isnull() and .notnull() Methods
#
# 6-The .between() Method
#
# 7-The .duplicated() Method / "~" does unique all values
#
# 8-The .drop_duplicates() Method
#
# 9-The .unique() and .nunique() Methods

# %%
import pandas as pd

# %%
df = pd.read_csv("files/employees.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
# to change data type from object to datetime. 
df["Start Date"] = pd.to_datetime(df["Start Date"])
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
# Last login time represent by time they don't include day/month/year informations. if we use this method we'll see today's information

df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-01-14 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-01-14 11:17:00  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df["Senior Management"] = df["Senior Management"].astype("bool")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-01-14 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-01-14 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-01-14 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-01-14 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %% [markdown]
# #### Filter A DataFrame Based On A Condition

# %%
df = pd.read_csv("files/employees.csv", parse_dates = ["Start Date","Last Login Time"])
#df["Start Date"] = pd.to_datetime(df["Start Date"])
#df["Last Login Time"] = pd.to_datetime(df["Last Login Time"]) 
# we used parse_dates function instead above 2 line. 
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-01-14 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-01-14 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
# we have this formula from earler cell: 
df = pd.read_csv("files/employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-01-14 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-01-14 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %% [markdown]
# ##### Equal ==

# %% [markdown]
# I'm actually going to use the python sign the language sign for comparison which is `the double equal` sign. Now you have to be very careful here because if you accidentally use the single equal sign what it's going to do is assign the values on the right to the values in that series.
#  So for example what I want to do here is compare to mail compare the values in the gender column to mail.
# If I accidentally forgot that second equals it's simply going to overwrite all of the values in the gender column with that string value of mail.

# %%
# if you want to have only male value you can use this formula: our data decreased1000 rows to 424 rows.

df[df["Gender"] == "Male"]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2021-01-14 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2021-01-14 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2021-01-14 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2021-01-14 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2021-01-14 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2021-01-14 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2021-01-14 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2021-01-14 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2021-01-14 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [424 rows x 8 columns]

# %%
# if you want to have only finance value at team you can use this formula: our data decreased1000 rows to 102 rows.

df[df["Team"] == "Finance"]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2021-01-14 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2021-01-14 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2021-01-14 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2021-01-14 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2021-01-14 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2021-01-14 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2021-01-14 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2021-01-14 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2021-01-14 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2021-01-14 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# 7                 True  Finance
# 14                True  Finance
# 46               False  Finance
# ..                 ...      ...
# 907              False  Finance
# 954               True  Finance
# 987               True  Finance
# 992               True  Finance
# 996              False  Finance
#
# [102 rows x 8 columns]

# %%
# Another way:
mask = df["Team"] == "Finance"
df[mask].head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2      Maria  Female 1993-04-23 2021-01-14 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2021-01-14 13:00:00  138705    9.340
# 7        NaN  Female 2015-07-20 2021-01-14 10:43:00   45906   11.598
#
#    Senior Management     Team
# 2              False  Finance
# 3               True  Finance
# 7               True  Finance

# %%
# for bool values: 

df[df["Senior Management"]]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2021-01-14 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2021-01-14 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2021-01-14 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2021-01-14 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2021-01-14 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2021-01-14 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2021-01-14 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2021-01-14 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2021-01-14 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 6                 True          Product
# ..                 ...              ...
# 991               True        Marketing
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 999               True            Sales
#
# [535 rows x 8 columns]

# %% [markdown]
# ##### Not Equal !=

# %%
# for finding not equal Marketing  values: 

df[df["Team"] != "Marketing"].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1     Thomas    Male 1996-03-31 2021-01-14 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-01-14 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2021-01-14 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2021-01-14 16:47:00  101004    1.389
# 5     Dennis    Male 1987-04-18 2021-01-14 01:35:00  115163   10.125
#
#    Senior Management             Team
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %% [markdown]
# ##### Less Than or Greater Than <>

# %%
df[df["Salary"] > 110000]

df[df["Bonus %"] < 1.5]. head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24 2021-01-14 16:47:00  101004    1.389
# 15     Lillian  Female 2016-06-05 2021-01-14 06:09:00   59414    1.256
# 58     Theresa  Female 2010-04-11 2021-01-14 07:18:00   72670    1.481
# 77     Charles    Male 2004-09-14 2021-01-14 20:13:00  107391    1.260
# 175     Willie    Male 1998-02-17 2021-01-14 20:20:00  146651    1.451
#
#      Senior Management             Team
# 4                 True  Client Services
# 15               False          Product
# 58                True      Engineering
# 77                True        Marketing
# 175               True      Engineering

# %% [markdown]
# ##### Greater than or equal to >= or less than or equal to <=

# %%
df[df["Start Date"] <= "1985-01-01"].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10     Louise  Female 1980-08-12 2021-01-14 09:01:00   63241   15.132
# 12    Brandon    Male 1980-12-01 2021-01-14 01:08:00  112807   17.492
# 18      Diana  Female 1981-10-23 2021-01-14 10:27:00  132940   19.082
# 28      Terry    Male 1981-11-27 2021-01-14 18:30:00  124008   13.464
# 37      Linda  Female 1981-10-19 2021-01-14 20:49:00   57427    9.557
#
#     Senior Management             Team
# 10               True              NaN
# 12               True  Human Resources
# 18              False  Client Services
# 28               True  Client Services
# 37               True  Client Services

# %% [markdown]
# #### Filter with More than One Condition (AND)

# %%
# we have this formula from earler cell: 
df = pd.read_csv("files/employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-01-14 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-01-14 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask1 = df["Gender"] == "Male"
mask2 = df["Team"] == "Marketing"

df[mask1 & mask2].head()
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas   Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
# 21    Matthew   Male 1995-09-05 2021-01-14 02:12:00  100612   13.645
# 26      Craig   Male 2000-02-27 2021-01-14 07:45:00   37598    7.757
# 74     Thomas   Male 1995-06-04 2021-01-14 14:24:00   62096   17.029
# 77    Charles   Male 2004-09-14 2021-01-14 20:13:00  107391    1.260
#
#     Senior Management       Team
# 0                True  Marketing
# 21              False  Marketing
# 26               True  Marketing
# 74              False  Marketing
# 77               True  Marketing

# %% [markdown]
# #### Filter with More than One Condition (OR)

# %%
# we have this formula from earler cell: 
df = pd.read_csv("files/employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-01-14 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-01-14 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask1 = df["Senior Management"] == True # You don't have to use == True. 
mask2 = df["Start Date"] < "1990-01-01"

df[mask1 | mask2].head()
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2021-01-14 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2021-01-14 13:00:00  138705    9.340
# 4      Larry   Male 1998-01-24 2021-01-14 16:47:00  101004    1.389
# 5     Dennis   Male 1987-04-18 2021-01-14 01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
mask1 = df["First Name"] == "Robert"
mask2 = df["Team"] == "Client Services"
mask3 = df["Start Date"] > "2016-06-01"

df[(mask1 & mask2) | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2021-01-14 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2021-01-14 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2021-01-14 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2021-01-14 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# #### The .isin() Method

# %%
# we have this formula from earler cell: 
df = pd.read_csv("files/employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(1)
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
#
#    Senior Management       Team
# 0               True  Marketing

# %%
# with "or" method:

mask1 = df["Team"] == "Legal"
mask2 = df["Team"] == "Sales"
mask3 = df["Team"] == "Product"

df[mask1 | mask2 | mask3].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male 1987-04-18 2021-01-14 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2021-01-14 16:20:00   65476   10.012
# 11      Julie  Female 1997-10-26 2021-01-14 15:19:00  102508   12.637
# 13       Gary    Male 2008-01-27 2021-01-14 23:40:00  109831    5.831
# 15    Lillian  Female 2016-06-05 2021-01-14 06:09:00   59414    1.256
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal
# 13              False    Sales
# 15              False  Product

# %%
# with .isin() method:

df[df["Team"].isin(["Legal","Sales","Product"])].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male 1987-04-18 2021-01-14 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2021-01-14 16:20:00   65476   10.012
# 11      Julie  Female 1997-10-26 2021-01-14 15:19:00  102508   12.637
# 13       Gary    Male 2008-01-27 2021-01-14 23:40:00  109831    5.831
# 15    Lillian  Female 2016-06-05 2021-01-14 06:09:00   59414    1.256
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal
# 13              False    Sales
# 15              False  Product

# %% [markdown]
# #### The .isnull() and .notnull() Methods

# %%
# we have this formula from earler cell: 
df = pd.read_csv("files/employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(1)
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
#
#    Senior Management       Team
# 0               True  Marketing

# %%
# if value is null it is going to turns True,if value is not null it  is going to turns False.
df["Team"].isnull() # true-false 
df[df["Team"].isnull()].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2021-01-14 06:53:00   61933    4.170
# 10     Louise  Female 1980-08-12 2021-01-14 09:01:00   63241   15.132
# 23        NaN    Male 2012-06-14 2021-01-14 16:19:00  125792    5.042
# 32        NaN    Male 1998-08-21 2021-01-14 14:27:00  122340    6.417
# 91      James     NaN 2005-01-26 2021-01-14 23:00:00  128771    8.309
#
#     Senior Management Team
# 1                True  NaN
# 10               True  NaN
# 23               True  NaN
# 32               True  NaN
# 91              False  NaN

# %%
# if value is not null it is going to turns True,if value is null it  is going to turns False.
df["Team"].notnull() # true-false 
df[df["Team"].notnull()].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
# 2      Maria  Female 1993-04-23 2021-01-14 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2021-01-14 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2021-01-14 16:47:00  101004    1.389
# 5     Dennis    Male 1987-04-18 2021-01-14 01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %% [markdown]
# #### The .between() Method

# %%
# we have this formula from earler cell: 
df = pd.read_csv("files/employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(1)
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
#
#    Senior Management       Team
# 0               True  Marketing

# %%
df[df["Salary"].between(60000, 70000)].head(3)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2021-01-14 06:53:00   61933    4.170
# 6        Ruby  Female 1987-08-17 2021-01-14 16:20:00   65476   10.012
# 10     Louise  Female 1980-08-12 2021-01-14 09:01:00   63241   15.132
#
#     Senior Management     Team
# 1                True      NaN
# 6                True  Product
# 10               True      NaN

# %%
df[df["Bonus %"].between(2.0, 5.0)].head(3)
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas   Male 1996-03-31 2021-01-14 06:53:00   61933    4.170
# 20       Lois    NaN 1995-04-22 2021-01-14 19:18:00   64714    4.934
# 40    Michael   Male 2008-10-10 2021-01-14 11:25:00   99283    2.665
#
#     Senior Management          Team
# 1                True           NaN
# 20               True         Legal
# 40               True  Distribution

# %%
df[df["Start Date"].between("1991-01-01", "1992-01-01")].head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11 2021-01-14 18:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02 2021-01-14 01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27 2021-01-14 13:59:00   64088    6.155
# 116        NaN    Male 1991-06-22 2021-01-14 20:58:00   76189   18.988
# 148    Patrick     NaN 1991-07-14 2021-01-14 02:24:00  124488   14.837
#
#      Senior Management             Team
# 27               False            Legal
# 75                True  Human Resources
# 88                True            Legal
# 116               True            Legal
# 148               True            Sales

# %% [markdown]
# #### The .duplicated() Method

# %%
# we have this formula from earler cell: 
df = pd.read_csv("files/employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace=True)
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2021-01-14 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2021-01-14 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2021-01-14 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
# First Aaron is false. That's meaning is first name not duplicate but others are duplicated. if we use .duplicated() method we have only duplicated values. 

df["First Name"].duplicated() #True-False
df[df["First Name"].duplicated()].head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron   Male 1994-01-29 2021-01-14 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2021-01-14 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2021-01-14 19:39:00   63126   18.424
# 141       Adam   Male 1990-12-24 2021-01-14 20:57:00  110194   14.727
# 302       Adam   Male 2007-07-05 2021-01-14 11:59:00   71276    5.027
#
#      Senior Management             Team
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 141               True          Product
# 302               True  Human Resources

# %%
# Last value accepted unique value(not duplicated). As default value is first value. 

df["First Name"].duplicated(keep = "last").head()
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# 137     True
# Name: First Name, dtype: bool

# %%
# First or last value is not matter in here. it is going to turn duplicated for all values. 

df["First Name"].duplicated(keep = False).head()
# Out:
# 101    True
# 327    True
# 440    True
# 937    True
# 137    True
# Name: First Name, dtype: bool

# %% [markdown]
# #### "~" does unique all values:

# %%
~df["First Name"].duplicated(keep = False).head()
# Out:
# 101    False
# 327    False
# 440    False
# 937    False
# 137    False
# Name: First Name, dtype: bool

# %%
~df["First Name"].duplicated(keep = False).value_counts()
# Out:
# True    -992
# False    -10
# Name: First Name, dtype: int64

# %%
# it shows just unique values: 

mask = ~df["First Name"].duplicated(keep = False)
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2021-01-14 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2021-01-14 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2021-01-14 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2021-01-14 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2021-01-14 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2021-01-14 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2021-01-14 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2021-01-14 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2021-01-14 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %% [markdown]
# #### The .drop_duplicates() Method

# %%
# we have this formula from earler cell: 
df = pd.read_csv("files/employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace=True)
df.head(1)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2021-01-14 10:20:00   61602   11.849
#
#      Senior Management       Team
# 101               True  Marketing

# %%
len(df)
# Out:
# 1000

# %%
# İf we call drop_duplicates() we are going to have all of our duplicates removed. 
# This method works when all columns values' be equal. 

len(df.drop_duplicates())
# Out:
# 1000

# %%
# We said with this formula: drop duplicates values by first name and keep only first "first name". 

df.drop_duplicates(subset = ["First Name"], keep = "first").head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2021-01-14 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2021-01-14 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2021-01-14 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2021-01-14 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2021-01-14 09:34:00   47638   11.209
#
#      Senior Management             Team
# 101               True        Marketing
# 137              False     Distribution
# 300               True      Engineering
# 372               True      Engineering
# 988              False  Human Resources

# %%
# We drop duplicates values by first name and team. And keep only first "first name". as a result, we have same name employees who are working at different team. 

df.drop_duplicates(subset = ["First Name","Team"], keep = "first").head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2021-01-14 10:20:00   61602   11.849
# 440      Aaron   Male 1990-07-22 2021-01-14 14:53:00   52119   11.343
# 137       Adam   Male 2011-05-21 2021-01-14 01:45:00   95327   15.120
# 141       Adam   Male 1990-12-24 2021-01-14 20:57:00  110194   14.727
# 302       Adam   Male 2007-07-05 2021-01-14 11:59:00   71276    5.027
#
#      Senior Management             Team
# 101               True        Marketing
# 440               True  Client Services
# 137              False     Distribution
# 141               True          Product
# 302               True  Human Resources

# %% [markdown]
# #### The .unique() and .nunique() Methods

# %%
# we have this formula from earler cell: 
df = pd.read_csv("files/employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(1)
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2021-01-14 12:42:00   97308    6.945
#
#    Senior Management       Team
# 0               True  Marketing

# %%
df["Gender"].unique()
# Out:
# ['Male', 'Female', NaN]
# Categories (2, object): ['Male', 'Female']

# %%
df["Team"].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
len(df["Team"].unique())
# Out:
# 11

# %% [markdown]
# `Number of unique value:as it turns out the n unique method by defult does not include or count no values that includes a parameter called "dropna = False". that parameter is set to an argument of true by defult.`

# %%
df["Team"].nunique()
# Out:
# 10

# %%
df["Team"].nunique(dropna = False)
# Out:
# 11
